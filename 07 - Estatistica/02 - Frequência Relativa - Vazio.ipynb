# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def calc_ticks(_list, bars):
    _list.sort()
    smaller_value = _list[0]
    bigger_value = _list[-1]
    interval = (bigger_value-smaller_value) / bars
    ticks = [smaller_value]
    last = smaller_value + interval
    ticks.append(last)
    for x in range(bars-1):
        last += interval
        ticks.append(last)
    return ticks

# %%
km = pd.Series([4, 8, 9, 11, 13, 15, 17, 17, 18, 19,
               30, 36, 39, 40, 45, 46, 46, 55, 59, 69])

# %%
_list = km.values
bars = 5
km.plot.hist(bins=bars, rwidth=0.95)
ticks = calc_ticks(_list, bars)
plt.xticks(ticks)
plt.title("Distance from home to work")
plt.xlabel('km')
plt.grid(axis='y')
plt.show()

# %%
def relative_frequency(total, yticks):
    rel_freq = []
    for item in yticks:
        x = item/total
        rel_freq.append(f"{x:.2f}%")
    return rel_freq

# %%
_list = km.values
bars = 5
ax = km.plot.hist(bins=bars, rwidth=0.95)
yticks = ax.get_yticks()
total = len(_list)
rel_freq = relative_frequency(total, yticks)
ax.set_yticklabels(rel_freq)

ticks = calc_ticks(_list, bars)
plt.xticks(ticks)
plt.title("Distance from home to work")
plt.xlabel('km')
plt.grid(axis='y')
plt.show()
# Out:
# /tmp/ipykernel_48720/2856314236.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(rel_freq)
