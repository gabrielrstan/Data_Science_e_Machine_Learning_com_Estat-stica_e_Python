# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
km = pd.Series([4, 8, 9, 11, 13, 15, 15, 17, 18, 19,
               35, 36, 39, 40, 45, 46, 46, 55, 59, 69])

# %%
km.plot.hist()
plt.show()

# %%
km.plot.hist(bins=5)
plt.show()

# %%
(69-4)/5
# Out:
# 13.0

# %%
ticks = [4, 17, 30, 43, 56, 69]

# %%
km.plot.hist(bins=5)
plt.xticks(ticks)
plt.title("Distance from home to work")
plt.xlabel('km')
plt.show()

# %%
km.plot.hist(bins=5, rwidth=0.95)
plt.xticks(ticks)
plt.title("Distance from home to work")
plt.xlabel('km')
plt.show()

# %%
km.plot.hist(bins=5, rwidth=0.95)
plt.xticks(ticks)
plt.title("Distance from home to work")
plt.xlabel('km')
plt.grid(axis='y')
plt.show()

# %%
def calc_ticks(_list, bars):
    smaller_value = _list[0]
    bigger_value = _list[-1]
    interval = (bigger_value-smaller_value) / bars
    ticks = [smaller_value]
    last = smaller_value + interval
    ticks.append(last)
    for x in range(bars-1):
        last += interval
        ticks.append(last)
    return ticks

# %%
_list = km.values
bars = 6
km.plot.hist(bins=bars, rwidth=0.95)
ticks = calc_ticks(_list, bars)
plt.xticks(ticks)
plt.title("Distance from home to work")
plt.xlabel('km')
plt.grid(axis='y')
plt.show()

# %%
km = pd.Series([4, 8, 9, 11, 13, 15, 17, 17, 18, 19,
               30, 36, 39, 40, 45, 46, 46, 55, 59, 69])

# %%
_list = km.values
bars = 5
km.plot.hist(bins=bars, rwidth=0.95)
ticks = calc_ticks(_list, bars)
plt.xticks(ticks)
plt.title("Distance from home to work")
plt.xlabel('km')
plt.grid(axis='y')
plt.show()
