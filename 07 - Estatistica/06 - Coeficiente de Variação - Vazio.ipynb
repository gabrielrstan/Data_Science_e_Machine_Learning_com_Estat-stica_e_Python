# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def calc_ticks(_list, bars):
    _list.sort()
    smaller_value = _list[0]
    bigger_value = _list[-1]
    interval = (bigger_value-smaller_value) / bars
    ticks = [smaller_value]
    last = smaller_value + interval
    ticks.append(last)
    for x in range(bars-1):
        last += interval
        ticks.append(last)
    return ticks

# %%
km = pd.Series([4, 8, 9, 11, 13, 15, 17, 17, 18, 19,
               30, 36, 39, 40, 45, 46, 46, 55, 59, 69])

# %%
def per_cent(x):
    x = x * 100
    return f'{x:.2f}%'

# %%
def relative_frequency(total, yticks):
    rel_freq = []
    for item in yticks:
        x = item/total
        rel_freq.append("{0:.2f}%".format(x*100))
    return rel_freq

# %%
def create_histogram(bars, data_series, title, unit):
    _list = data_series.values
    ax = data_series.plot.hist(bins=bars, rwidth=0.95)

    yticks = ax.get_yticks()
    total = len(_list)
    freq_rel = relative_frequency(total, yticks)
    ax.set_yticklabels(freq_rel)

    fig = plt.gcf()
    fig.set_size_inches(10, 5)
    fig.set_dpi(150)

    ticks = calc_ticks(_list, bars)
    plt.xticks(ticks)
    plt.title(title)
    plt.xlabel(unit)
    plt.grid(axis='y')
    plt.show()

# %%
create_histogram(5, km, 'Distance', 'km')
# Out:
# /tmp/ipykernel_7375/4059694908.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(freq_rel)

# %%
data = pd.read_csv('weight-height.csv')

# %%
data['Height_cm'] = data['Height'] * 2.54

# %%
data['Height_cm'] = data['Height_cm'].round()

# %%
height_women = data.loc[data['Gender'] == 'Female']['Height_cm']
height_men = data.loc[data['Gender'] == 'Male']['Height_cm']

# %%
create_histogram(9, height_women, 'Height Women', 'cm')
# Out:
# /tmp/ipykernel_7375/4059694908.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(freq_rel)

# %%
create_histogram(9, height_men, 'Height Men', 'cm')
# Out:
# /tmp/ipykernel_7375/4059694908.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(freq_rel)

# %%
data.head()
# Out:
#   Gender     Height      Weight  Height_cm
# 0   Male  73.847017  241.893563      188.0
# 1   Male  68.781904  162.310473      175.0
# 2   Male  74.110105  212.740856      188.0
# 3   Male  71.730978  220.042470      182.0
# 4   Male  69.881796  206.349801      177.0

# %%
import statistics as stats

# %% [markdown]
# # Média
#
# Somatório de valores de determinados elementos dividido pela quantidade de elementos somados.

# %%
stats.mean(height_women)
# Out:
# 161.8112

# %%
stats.mean(height_men)
# Out:
# 175.327

# %% [markdown]
# # Mediana
#
# Dada uma sequência de valores ordenados em ordem crescente ou decrescente, a mediana é o valor central dessa sequência. Caso haja dois valores centrais, a mediana é dada pela média aritmética deles.

# %%
stats.median(height_women)
# Out:
# 162.0

# %%
stats.median(height_men)
# Out:
# 175.0

# %% [markdown]
# # Moda
#
# Dado um conjunto de valores, a moda é o número que mais se repete.

# %%
stats.mode(height_men)
# Out:
# 175.0

# %%
len(height_men)data = pd.read_csv('weight-height.csv')
# Out:
# 5000

# %%
five = height_men.head()
five
# Out:
# 0    148.0
# 1    151.0
# 2    152.0
# 3    152.0
# 4    152.0
# Name: Height_cm, dtype: float64

# %%
mean = stats.mean(five)
mean
# Out:
# 151.0

# %%
n = len(five)
n
# Out:
# 5

# %% [markdown]
# <center><h2>Variância - População</h2></center>

# %% [markdown]
# $$\sigma^{2} = {\frac {\sum _{i=1}^{N}(x_{i}-\mu )^{2}}{N}}$$

# %% [markdown]
# <center><h2>Variância - Amostra</h2></center>

# %% [markdown]
# $$s^{2}={\frac {\sum _{i=1}^{n}(x_{i}-{\overline {x}})^{2}}{n-1}}$$

# %%
var = stats.variance(five)
var
# Out:
# 3.0

# %% [markdown]
# ## Desvio Padrão - População

# %% [markdown]
# $\sqrt{\sigma^{2}}=\sigma$

# %% [markdown]
# ## Desvio Padrão - Amostra

# %% [markdown]
# $\sqrt{S^{2}}=S$

# %%
import math

# %%
s = math.sqrt(var)
s
# Out:
# 1.7320508075688772

# %%
stats.stdev(five)
# Out:
# 1.7320508075688772

# %%
mean_height_women = stats.mean(height_women)
mean_height_women
# Out:
# 161.8112

# %%
dp_height_women = stats.stdev(height_women)
dp_height_women
# Out:
# 6.850207268975559

# %%
mean_height_men = stats.mean(height_men)
mean_height_men
# Out:
# 175.327

# %%
dp_height_men = stats.stdev(height_men)
dp_height_men
# Out:
# 7.286747582980188

# %% [markdown]
# ## Coeficiente de Variação - População

# %% [markdown]
# $$CV = {\frac \sigma {\mu}}$$

# %% [markdown]
# ## Coeficiente de Variação - Amostra

# %% [markdown]
# $$CV = {\frac S {\overline {x}}}$$

# %%
cv_height_women = dp_height_women / mean_height_women
cv_height_women
# Out:
# 0.04233456811997908

# %%
per_cent(cv_height_women)
# Out:
# '4.23%'

# %%
cv_height_men = dp_height_men / mean_height_men
cv_height_men
# Out:
# 0.04156089811027502

# %%
per_cent(cv_height_men)
# Out:
# '4.16%'

# %%
data.head()
# Out:
#   Gender     Height      Weight  Height_cm
# 0   Male  73.847017  241.893563      188.0
# 1   Male  68.781904  162.310473      175.0
# 2   Male  74.110105  212.740856      188.0
# 3   Male  71.730978  220.042470      182.0
# 4   Male  69.881796  206.349801      177.0

# %%
data['Weight_kg'] = data['Weight'] * 0.4535922

# %%
data.head()
# Out:
#   Gender     Height      Weight  Height_cm   Weight_kg
# 0   Male  73.847017  241.893563      188.0  109.721033
# 1   Male  68.781904  162.310473      175.0   73.622764
# 2   Male  74.110105  212.740856      188.0   96.497593
# 3   Male  71.730978  220.042470      182.0   99.809548
# 4   Male  69.881796  206.349801      177.0   93.598660

# %%
data['Weight_kg'] = data['Weight_kg'].round(1)

# %%
data.head()
# Out:
#   Gender     Height      Weight  Height_cm  Weight_kg
# 0   Male  73.847017  241.893563      188.0      109.7
# 1   Male  68.781904  162.310473      175.0       73.6
# 2   Male  74.110105  212.740856      188.0       96.5
# 3   Male  71.730978  220.042470      182.0       99.8
# 4   Male  69.881796  206.349801      177.0       93.6

# %%
weight_women = data.loc[data['Gender'] == 'Female']['Weight_kg']
weight_men = data.loc[data['Gender'] == 'Male']['Weight_kg']

# %%
create_histogram(9, weight_men, 'Weight Men', 'kg')
# Out:
# /tmp/ipykernel_7375/4059694908.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(freq_rel)

# %%
create_histogram(9, weight_women, 'Weight Women', 'kg')
# Out:
# /tmp/ipykernel_7375/4059694908.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(freq_rel)

# %%
dp_weight_women = stats.stdev(weight_women)
dp_weight_men = stats.stdev(weight_men)

# %%
mean_weight_women = stats.mean(weight_women)
mean_weight_men = stats.mean(weight_men)

# %%
cv_weight_women = dp_weight_women / mean_weight_women
cv_weight_women
# Out:
# 0.1400207555856948

# %%
per_cent(cv_weight_women)
# Out:
# '14.00%'

# %%
cv_weight_men = dp_weight_men / mean_weight_men
cv_weight_men
# Out:
# 0.10576821767294878

# %%
per_cent(cv_weight_men)
# Out:
# '10.58%'

# %%
cv_dict = {
    'men': {'cv_weigth': per_cent(cv_weight_men), 'cv_height': per_cent(cv_height_men)},
    'women': {'cv_weigth': per_cent(cv_weight_women), 'cv_height': per_cent(cv_height_women)}
}

# %%
cv_dict
# Out:
# {'men': {'cv_weigth': '10.58%', 'cv_height': '4.16%'},
#  'women': {'cv_weigth': '14.00%', 'cv_height': '4.23%'}}

# %%
cv = pd.DataFrame.from_dict(cv_dict)

# %%
cv
# Out:
#               men   women
# cv_weigth  10.58%  14.00%
# cv_height   4.16%   4.23%
